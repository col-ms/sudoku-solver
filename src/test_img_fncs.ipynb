# %%
import pandas as pd
import os
import random
import matplotlib.pyplot as plt
import read_puzzle
import cv2
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0x10 but this version of numpy is 0xf
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# c:\Users\colli\Documents\Github Repos\sudoku-solver\src\test_img_fncs.ipynb Cell 1 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/colli/Documents/Github%20Repos/sudoku-solver/src/test_img_fncs.ipynb#ch0000000?line=2'>3</a> import random
#       <a href='vscode-notebook-cell:/c%3A/Users/colli/Documents/Github%20Repos/sudoku-solver/src/test_img_fncs.ipynb#ch0000000?line=3'>4</a> import matplotlib.pyplot as plt
# ...

# %%
folder = "../data/puzzle_imgs"

img_list = []
for file_name in os.listdir(folder):
    img_list.append(file_name)

puzzle_file = random.choice(img_list)
print(puzzle_file)
puzzle_img = cv2.imread(folder + "/" + puzzle_file)
plt.figure()
plt.imshow(puzzle_img)
plt.show()
# Out:
# sudoku_real_5.jpg

# %%
pre_proc_img = read_puzzle.pre_process_img(puzzle_img)
plt.figure()
plt.imshow(pre_proc_img)
plt.show()

# %%
puzzle_bounds = read_puzzle.find_puzzle_bounds(pre_proc_img)
print(puzzle_bounds)
# Out:
# [array([54, 64], dtype=int32), array([369,  52], dtype=int32), array([390, 392], dtype=int32), array([ 25, 387], dtype=int32)]

# %%
new_puzzle_img = read_puzzle.crop_and_warp(pre_proc_img, puzzle_bounds)
plt.figure()
plt.imshow(new_puzzle_img)
plt.show()

# %%
import custom_mnist as cm

# %%
train_set = cm.PrintedMNIST(100, -20)

# %%
train_set.__getitem__(3)
# Out:
# (<PIL.Image.Image image mode=L size=28x28>, 1)

# %%
train_set.__fonts__()[0]
# Out:
# '../fonts\\arial-bold.ttf'

# %%
import glob
fonts_folder = "../fonts"
fonts_list = glob.glob(fonts_folder + "/*.ttf")

# %%
print(fonts_list)
import random
random.choice(fonts_list)
# Out:
# ['../fonts\\arial-bold.ttf', '../fonts\\Helvetica-Bold-Font.ttf']
# '../fonts\\Helvetica-Bold-Font.ttf'
